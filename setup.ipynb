# %%
! python --version
# Out:
# Python 3.7.3

# %%
import pandas as pd

# %%
# !ls /home/ubuntu/f1/data/
# Out:
# circuits.csv		   driver_standings.csv  qualifying.csv  status.csv
# constructor_results.csv    drivers.csv		 races.csv
# constructor_standings.csv  lap_times.csv	 results.csv
# constructors.csv	   pit_stops.csv	 seasons.csv

# %%
qualifying=pd.read_csv('/home/ubuntu/f1/data/qualifying.csv')
qualifying.info()
qualifying[qualifying.raceId==1034].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8414 entries, 0 to 8413
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   qualifyId      8414 non-null   int64
#  1   raceId         8414 non-null   int64
#  2   driverId       8414 non-null   int64
#  3   constructorId  8414 non-null   int64
#  4   number         8414 non-null   int64
#  5   position       8414 non-null   int64
#  6   q1             8406 non-null   object
#  7   q2             8290 non-null   object
#  8   q3             8180 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 591.7+ KB
# Empty DataFrame
# Columns: [qualifyId, raceId, driverId, constructorId, number, position, q1, q2, q3]
# Index: []

# %%
qualifying[qualifying.raceId==1033]
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 8394       8418    1033       822            131      77         2  1:15.474
# 8395       8419    1033       840            211      18         3  1:14.895
# 8396       8420    1033       815            211      11         4  1:14.681
# 8397       8421    1033        20              6       5         5  1:15.455
# 8398       8422    1033       844              6      16         6  1:15.793
# 8399       8423    1033       830              9      33         7  1:15.495
# 8400       8424    1033       846              1       4         8  1:15.444
# 8401       8425    1033       832              1      55         9  1:15.281
# 8402       8426    1033       842            213      10        10  1:15.767
# 8403       8427    1033       817              4       3        11  1:15.848
# 8404       8428    1033       847              3      63        12  1:15.585
# ...

# %%
races=pd.read_csv('/home/ubuntu/f1/data/races.csv')
races.info()
races[races.year==2020].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1026 entries, 0 to 1025
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   raceId     1026 non-null   int64
#  1   year       1026 non-null   int64
#  2   round      1026 non-null   int64
#  3   circuitId  1026 non-null   int64
#  4   name       1026 non-null   object
#  5   date       1026 non-null   object
#  6   time       1026 non-null   object
#  7   url        1026 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 64.2+ KB
#       raceId  year  round  circuitId                         name        date  \
# 1018    1031  2020      1         70          Austrian Grand Prix  2020-07-05
# 1019    1032  2020      2         70           Styrian Grand Prix  2020-07-12
# 1020    1033  2020      3         11         Hungarian Grand Prix  2020-07-19
# 1021    1034  2020      4          9           British Grand Prix  2020-08-02
# ...

# %%
drivers=pd.read_csv('/home/ubuntu/f1/data/drivers.csv')
drivers.info()
drivers.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848 entries, 0 to 847
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     848 non-null    int64
#  1   driverRef    848 non-null    object
#  2   number       848 non-null    object
#  3   code         848 non-null    object
#  4   forename     848 non-null    object
#  5   surname      848 non-null    object
#  6   dob          848 non-null    object
#  7   nationality  848 non-null    object
#  8   url          847 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 59.8+ KB
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# ...

# %%
driver_standings=pd.read_csv('/home/ubuntu/f1/data/driver_standings.csv')
driver_standings.info()
driver_standings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32646 entries, 0 to 32645
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   driverStandingsId  32646 non-null  int64
#  1   raceId             32646 non-null  int64
#  2   driverId           32646 non-null  int64
#  3   points             32646 non-null  float64
#  4   position           32646 non-null  int64
#  5   positionText       32646 non-null  object
#  6   wins               32646 non-null  int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 1.7+ MB
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# ...

# %%
drivers.driverRef.unique()
# Out:
# array(['hamilton', 'heidfeld', 'rosberg', 'alonso', 'kovalainen',
#        'nakajima', 'bourdais', 'raikkonen', 'kubica', 'glock', 'sato',
#        'piquet_jr', 'massa', 'coulthard', 'trulli', 'sutil', 'webber',
#        'button', 'davidson', 'vettel', 'fisichella', 'barrichello',
#        'ralf_schumacher', 'liuzzi', 'wurz', 'speed', 'albers',
#        'markus_winkelhock', 'yamamoto', 'michael_schumacher', 'montoya',
#        'klien', 'monteiro', 'ide', 'villeneuve', 'montagny', 'rosa',
#        'doornbos', 'karthikeyan', 'friesacher', 'zonta', 'pizzonia',
#        'matta', 'panis', 'pantano', 'bruni', 'baumgartner', 'gene',
#        'frentzen', 'verstappen', 'wilson', 'firman', 'kiesa', 'burti',
#        'alesi', 'irvine', 'hakkinen', 'marques', 'bernoldi', 'mazzacane',
#        'enge', 'yoong', 'salo', 'diniz', 'herbert', 'mcnish', 'buemi',
#        'takagi', 'badoer', 'zanardi', 'damon_hill', 'sarrazin', 'rosset',
# ...

# %%
drivers[drivers.driverRef=='hamilton'].driverId.values[0]
# Out:
# 1

# %%
driver_standings[driver_standings.driverId==drivers[drivers.driverRef=='hamilton'].driverId.values[0]].position.value_counts(dropna=False)
# Out:
# 1     104
# 2      63
# 4      31
# 3      21
# 5      15
# 6       6
# 7       5
# 11      3
# 10      2
# 19      1
# 9       1
# 8       1
# Name: position, dtype: int64

# %%
driver_standings[driver_standings.driverId==drivers[drivers.driverRef=='alonso'].driverId.values[0]].position.value_counts(dropna=False)
# Out:
# 1     52
# 2     40
# 5     35
# 3     26
# 4     24
# 6     15
# 9     14
# 8     14
# 23    11
# 10    10
# 15    10
# 11    10
# 7      9
# 16     9
# 17     9
# 12     5
# 18     5
# 19     5
# 21     4
# 13     3
# 14     3
# 20     3
# Name: position, dtype: int64

# %%
circuits=pd.read_csv('/home/ubuntu/f1/data/circuits.csv')
circuits.info()
circuits.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   74 non-null     int64
#  1   circuitRef  74 non-null     object
#  2   name        74 non-null     object
#  3   location    74 non-null     object
#  4   country     74 non-null     object
#  5   lat         74 non-null     float64
#  6   lng         74 non-null     float64
#  7   alt         74 non-null     object
#  8   url         74 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.3+ KB
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# ...
